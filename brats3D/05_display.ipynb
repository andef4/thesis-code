# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../brats/')
from plot_utils import plot_image_row

# %%
flair = np.load('images/Brats18_2013_17_1/flair.npy')
t1 = np.load('images/Brats18_2013_17_1/t1.npy')
t1ce = np.load('images/Brats18_2013_17_1/t1ce.npy')
t2 = np.load('images/Brats18_2013_17_1/t2.npy')

for i in range(len(flair)):
    plot_image_row([t1[i], t1ce[i], t2[i], flair[i]], labels=['T1', 'T1ce', 'T2', 'Flair'])
